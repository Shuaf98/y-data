# %%
# %pylab inline
plt.style.use("bmh")

import numpy as np
import torch
from sklearn import datasets
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
torch.manual_seed(8436) #This is important with model training, as we need to try and reproduce our models to train them and check them.
a = torch.Tensor(1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-427440cb904a> in <module>
#       1 torch.manual_seed(8436) #This is important with model training, as we need to try and reproduce our models to train them and check them.
# ----> 2 a = torch.Tensor(1000).torch.float()
#
# AttributeError: 'Tensor' object has no attribute 'torch'

# %%
a.normal_(0, 2.)
plt.hist(a);
