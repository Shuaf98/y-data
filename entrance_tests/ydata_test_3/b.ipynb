# %%
import pandas as pd

# %%
df = pd.read_csv('insurance_data.csv')
age = df[(df['age'] >= 35) & (df['age'] <=39)]
age[age['claim'] == 0].count()
# Out:
# logged          2440
# agency_type     2440
# channel         2440
# duration        2440
# product_code    2440
# policy_code     2440
# destination     2440
# net_sales       2440
# comission       2440
# age             2440
# claim           2440
# Unnamed: 11        0
# Unnamed: 12        1
# Unnamed: 13        1
# Unnamed: 14        1
# dtype: int64

# %%
688+4812
# Out:
# 5500

# %%
199/2440
# Out:
# 0.08155737704918033

# %%
# Out:
#                logged    agency_type channel  duration  product_code  \
# 0     01022019--11:24  Travel Agency  Online        15          7791
# 1     01022019--11:40  Travel Agency  Online        28          9136
# 2     01022019--11:52       Airlines  Online        43          4356
# 3     01022019--11:58       Airlines  Online         9          4391
# 4     01022019--14:36  Travel Agency  Online         7          9172
# ...               ...            ...     ...       ...           ...
# 5495  31102019--18:21  Travel Agency  Online         6          9181
# 5496  31102019--18:30  Travel Agency  Online        15          7758
# 5497  31102019--18:39  Travel Agency  Online       107          5861
# 5498  31102019--18:56  Travel Agency  Online         8          7745
# 5499  31102019--23:57  Travel Agency  Online       216          7792
#
#             policy_code     destination  net_sales  comission  age  claim  \
# ...
