# %%
import pandas as pd
import numpy as np

df = pd.read_csv('schools (1).csv')
df= df[df['Student Attendance Rate'].str.rstrip('%').astype('int')/100 > 0]
df = df[df['Rigorous Instruction'].str.rstrip('%').astype('int')/100 > 0]
df = df[df['Students Chronically Absent'].str.rstrip('%').astype('int')/100 < 1]

df = df.dropna(subset = ['Student Achievement Rating' , 'Average Proficiency Score'])

def change(n):
    if n == 'Exceeding Target': return 1.0
    if n == 'Meeting Target': return 0.8
    if n == 'Approaching Target': return 0.5
    if n == 'Not Meeting Target': return 0.0
df['Student Achievement Rating'] = df['Student Achievement Rating'].apply(change)

# df.loc[df['Student Achievement Rating'] == 'Exceeding Target', ['Student Achievement Rating']] = 1
# df.loc[df['Student Achievement Rating'] == 'Meeting Target', ['Student Achievement Rating']] = 0.8
# df.loc[df['Student Achievement Rating'] == 'Approaching Target', ['Student Achievement Rating']] = 0.5
# df.loc[df['Student Achievement Rating'] == 'Not Meeting Target', ['Student Achievement Rating']] = 0.0

result = df.to_csv('result.csv', index = False)
df
# Out:
#       School Index  District Lowest Year Highest Year School Income Estimate  \
# 0           310001         5           6            8                    NaN
# 1           310002         2          PK            5            $26,114.78
# 2           310003         2          PK            5           $103,399.19
# 3           310004         6          PK            5            $34,684.21
# 4           310005         6          0K            5            $29,783.60
# ...            ...       ...         ...          ...                    ...
# 1242        353080        31          0K           12            $67,750.03
# 1243        353861        31          PK            8            $67,543.01
# 1244        353959        31           6           12                    NaN
# 1245        353964        31          0K            8            $48,091.89
# 1246        353984        31           6            8                    NaN
#
#      Average Proficiency Score Student Attendance Rate  \
# 0                          65%                     94%
# 1                          69%                     98%
# 2                          77%                     95%
# 3                          56%                     92%
# 4                          53%                     93%
# ...                        ...                     ...
# 1242                       71%                     95%
# 1243                       70%                     94%
# 1244                       60%                     94%
# 1245                       59%                     95%
# 1246                       61%                     95%
#
#      Students Chronically Absent Rigorous Instruction  \
# 0                            19%                  97%
# 1                             6%                  93%
# 2                            13%                  97%
# 3                            33%                  91%
# 4                            26%                  89%
# ...                          ...                  ...
# 1242                         10%                  93%
# 1243                         17%                  94%
# 1244                         15%                  88%
# 1245                         14%                  89%
# 1246                         14%                  91%
#
#       Year 3 - All Students Tested  Year 4 - All Students Tested  \
# 0                                0                             0
# 1                              125                           106
# 2                              105                           142
# 3                              103                           100
# 4                               90                            90
# ...                            ...                           ...
# 1242                            85                            96
# 1243                           100                            99
# 1244                             0                             0
# 1245                            42                            36
# 1246                             0                             0
#
#       Year 5 - All Students Tested  Year 6 - All Students Tested  \
# 0                                0                           104
# 1                              104                             0
# 2                               61                             0
# 3                               81                             0
# 4                               69                             0
# ...                            ...                           ...
# 1242                           106                           101
# 1243                            66                           100
# 1244                             0                           129
# 1245                            54                             0
# 1246                             0                           130
#
#       Year 3 - Top Scoring  Year 4 - Top Scoring  Year 5 - Top Scoring  \
# 0                        0                     0                     0
# 1                        8                    13                    11
# 2                        9                    44                    18
# 3                        3                     7                     1
# 4                        0                     7                     1
# ...                    ...                   ...                   ...
# 1242                    12                    10                     9
# 1243                    24                    17                    15
# 1244                     0                     0                     0
# 1245                     4                     5                     2
# 1246                     0                     0                     0
#
#       Year 6 - Top Scoring  Student Achievement Rating
# 0                        8                         1.0
# 1                        0                         0.8
# 2                        0                         0.8
# 3                        0                         0.5
# 4                        0                         0.5
# ...                    ...                         ...
# 1242                    16                         0.8
# 1243                    14                         1.0
# 1244                    10                         0.8
# 1245                     0                         0.5
# 1246                     9                         1.0
#
# [1176 rows x 18 columns]

# %%
df= df[df['Student Attendance Rate'].str.strip('%').astype('int')/100 >= 0]
df = df[df['Rigorous Instruction'].str.strip('%').astype('int')/100 >= 0]
df = df[df['Students Chronically Absent'].str.strip('%').astype('int')/100 < 1]

df.head()
# Out:
#    School Index  District Lowest Year Highest Year School Income Estimate  \
# 0        310001         5           6            8                    NaN
# 1        310002         2          PK            5            $26,114.78
# 2        310003         2          PK            5           $103,399.19
# 3        310004         6          PK            5            $34,684.21
# 4        310005         6          0K            5            $29,783.60
#
#   Average Proficiency Score Student Attendance Rate  \
# 0                       65%                     94%
# 1                       69%                     98%
# 2                       77%                     95%
# 3                       56%                     92%
# 4                       53%                     93%
#
#   Students Chronically Absent Rigorous Instruction  \
# 0                         19%                  97%
# 1                          6%                  93%
# 2                         13%                  97%
# 3                         33%                  91%
# 4                         26%                  89%
#
#    Year 3 - All Students Tested  Year 4 - All Students Tested  \
# 0                             0                             0
# 1                           125                           106
# 2                           105                           142
# 3                           103                           100
# 4                            90                            90
#
#    Year 5 - All Students Tested  Year 6 - All Students Tested  \
# 0                             0                           104
# 1                           104                             0
# 2                            61                             0
# 3                            81                             0
# 4                            69                             0
#
#    Year 3 - Top Scoring  Year 4 - Top Scoring  Year 5 - Top Scoring  \
# 0                     0                     0                     0
# 1                     8                    13                    11
# 2                     9                    44                    18
# 3                     3                     7                     1
# 4                     0                     7                     1
#
#    Year 6 - Top Scoring  Student Achievement Rating
# 0                     8                         1.0
# 1                     0                         0.8
# 2                     0                         0.8
# 3                     0                         0.5
# 4                     0                         0.5
